# %%
import sys
import os

# Añadimos la carpeta padre (la raíz del proyecto) al path de Python
sys.path.append(os.path.abspath('..'))

# %%
from config_loader import cfg

# Validar que lee las variables correctamente
print(f"Catálogo Trusted Activo: {cfg.catalogo_trusted}")
print(f"Catálogo Landing Activo: {cfg.catalogo_landing}")
